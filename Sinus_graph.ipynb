# %%
import numpy as np
from numpy import pi, sqrt
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

# %%
x = np.linspace(-6 * np.pi, 6 * np.pi, 150)
F = lambda x: np.sin(x)/x

# %%
#Design
fig, ax = plt.subplots(figsize=(20, 10))
# Plotting
ax.plot(x/np.pi, F(x), linewidth=3, color="g", label=r'$F(x)$')
ax.xaxis.set_major_formatter(tck.FormatStrFormatter('%g $\pi$'))
ax.xaxis.set_major_locator(tck.MultipleLocator(base=1/2))
plt.grid(color='black', linestyle='-', linewidth=0.5)
#fig.savefig("sinx.png")
plt.show()

# %%
#set(gca,'XTickLabel',{'-6*pi','-5*pi/2','-2*pi','-3*pi/2','-1*pi','-1*pi/2',,'-1*pi'})
#ax.XTickLabel = {'-6*pi','-5*pi/2','-2*pi','-3*pi/2','-1*pi','-1*pi/2',,'-1*pi'};
set(gca,'XTick',-2*pi:pi:2*pi)
ax.XTickLabel = {'-2\pi','-\pi','0','\pi','2\pi'};
# Out:
#   File "<ipython-input-4-aadc70af0987>", line 3
#     set(gca,'XTick',-2*pi:pi:2*pi)
#                          ^
# SyntaxError: invalid syntax

# %%
# ?plt.hist
